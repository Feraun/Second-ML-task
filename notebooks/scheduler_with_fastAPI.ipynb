# %% [markdown]
# Проверка шедулера с фастАПИ
#
# перед ноутбуком надо запустить fastAPI
#
# <i><b>uvicorn fastAPI.main:app</b></i>

# %%
from scheduler import start_scheduler

configs = [
    {"iterations": 200, "depth": 4, "learning_rate": 0.1},
    # {"iterations": 300, "depth": 6, "learning_rate": 0.1},
    # {"iterations": 500, "depth": 6, "learning_rate": 0.05},
    # {"iterations": 700, "depth": 8, "learning_rate": 0.03},
]

start_scheduler(configs)
# Out:
# Scheduler started
# API status: 200
# API status: 200
